# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('superstore_data.csv')
data.head()
# Out:
#           order_id  gmv  profit  quantity         category sub_category  cost  \
# 0   AZ-2011-252578  444      89         4       Technology       Phones   355
# 1   AZ-2011-252578   39      10         6  Office Supplies      Binders    29
# 2  AZ-2014-9539724  485     199         4  Office Supplies      Storage   286
# 3  AZ-2014-1861968  232      85         3  Office Supplies   Appliances   147
# 4   AZ-2013-503783  299     116         4  Office Supplies   Appliances   183
#
#    total_gmv  total_cost  total_profit order_date         customer_name city  \
# 0       1776         355           356  4/21/2011  Sebastian McClelland  Elx
# 1        234          29            60  4/21/2011  Sebastian McClelland  Elx
# 2       1940         286           796  8/29/2014          Alice Currie  Elx
# 3        696         147           255   5/7/2014         Mark Westfall  Pau
# 4       1196         183           464   1/1/2013          Freddie Kaur  Pau
#
# ...

# %%
data[data['country'] == 'Spain']['total_profit'].sum()
# Out:
# np.int64(305658)
